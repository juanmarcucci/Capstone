# %% [markdown]
# ## Los Angeles AirBnb EDA

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airbnb = pd.read_csv('./listings_1.csv')

# %%
airbnb.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   65467   https://www.airbnb.com/rooms/65467  20221206172243   2022-12-07
# 1  206662  https://www.airbnb.com/rooms/206662  20221206172243   2022-12-07
# 2   67089   https://www.airbnb.com/rooms/67089  20221206172243   2022-12-07
# 3  210489  https://www.airbnb.com/rooms/210489  20221206172243   2022-12-07
# 4     109     https://www.airbnb.com/rooms/109  20221206172243   2022-12-07
#
#         source                                               name  \
# 0  city scrape                       A Luxury Home in Los Angeles
# 1  city scrape                 Hollywood & Hiking, 30 day minimum
# 2  city scrape           Tranquil Guesthouse Oasis with a Hot Tub
# 3  city scrape                3br 3ba townhome near Beverly Hills
# 4  city scrape  Amazing bright elegant condo park front *UPGRA...
#
#                                          description  \
# 0  <b>The space</b><br />Private 16 x 15 ft room ...
# ...

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40438 entries, 0 to 40437
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            40438 non-null  int64
#  1   listing_url                                   40438 non-null  object
#  2   scrape_id                                     40438 non-null  int64
#  3   last_scraped                                  40438 non-null  object
#  4   source                                        40438 non-null  object
#  5   name                                          40436 non-null  object
#  6   description                                   39701 non-null  object
#  7   neighborhood_overview                         23505 non-null  object
#  8   picture_url                                   40438 non-null  object
# ...

# %% [markdown]
# ### Feature Selection

# %%
features = ['host_id', 'host_location', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'price', 'minimum_minimum_nights', 'maximum_maximum_nights', 'availability_365', 'number_of_reviews_ltm', 'license', 'instant_bookable', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms']

q_hosts = airbnb[features]

q_hosts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40438 entries, 0 to 40437
# Data columns (total 15 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_id                                       40438 non-null  int64
#  1   host_location                                 32661 non-null  object
#  2   neighbourhood_cleansed                        40438 non-null  object
#  3   neighbourhood_group_cleansed                  40438 non-null  object
#  4   price                                         40438 non-null  object
#  5   minimum_minimum_nights                        40433 non-null  float64
#  6   maximum_maximum_nights                        40433 non-null  float64
#  7   availability_365                              40438 non-null  int64
#  8   number_of_reviews_ltm                         40438 non-null  int64
# ...

# %%
q_hosts.isnull().sum()
# Out:
# host_id                                             0
# host_location                                    7777
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                        0
# price                                               0
# minimum_minimum_nights                              5
# maximum_maximum_nights                              5
# availability_365                                    0
# number_of_reviews_ltm                               0
# license                                         30176
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# dtype: int64

# %% [markdown]
# ### Plan for Nulls

# %% [markdown]
# Host Location = fill with 'undisclosed'\
# mmn and mmn = fill with 1 and 365 respectively, assuming it's undisclosed to circunvent law\
# license = binarize, has or does not have license

# %% [markdown]
# ### Feature Engineering

# %%
# Binarize license column

# %%
# Graph

# %%
# Problem Statement

# %%
# Initial Modeling
